# %%
import json
import requests

# %%
response = requests.get("http://www.fruityvice.com/api/fruit/banana")

# %%
print(response)
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '{"name":"Banana","id":1,"family":"Musaceae","order":"Zingiberales","genus":"Musa","nutritions":{"calories":96,"fat":0.2,"sugar":17.2,"carbohydrates":22.0,"protein":1.0}}'

# %%
json.loads(response.text)
# Out:
# {'name': 'Banana',
#  'id': 1,
#  'family': 'Musaceae',
#  'order': 'Zingiberales',
#  'genus': 'Musa',
#  'nutritions': {'calories': 96,
#   'fat': 0.2,
#   'sugar': 17.2,
#   'carbohydrates': 22.0,
#   'protein': 1.0}}

# %%
response = requests.get("http://goweather.herokuapp.com/weather/Mashhad")
response.text
# Out:
# '{"temperature":"0 °C","wind":"19 km/h","description":"Partly cloudy","forecast":[{"day":"1","temperature":"-1 °C","wind":"4 km/h"},{"day":"2","temperature":"1 °C","wind":"6 km/h"},{"day":"3","temperature":"4 °C","wind":"5 km/h"}]}'

# %%
response = requests.get("http://goweather.herokuapp.com/weather/Mashhad")
json.loads(response.text)
# Out:
# {'temperature': '0 °C',
#  'wind': '19 km/h',
#  'description': 'Partly cloudy',
#  'forecast': [{'day': '1', 'temperature': '-1 °C', 'wind': '4 km/h'},
#   {'day': '2', 'temperature': '1 °C', 'wind': '6 km/h'},
#   {'day': '3', 'temperature': '4 °C', 'wind': '5 km/h'}]}

# %%
response = requests.get("https://thispersondoesnotexist.com")

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00CC"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1e\x00\x00\x01\x05\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x03\x04\x02\x05\x06\x01\x07\x00\x08\t\n\xff\xc4\x00\x1c\x01\x00\x02\x03\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x03\x01\x04\x00\x05\x06\x07\x08\xff\xda\x00\x0c\x03\x01\x00\x02\x10\x03\x10\x00\x00\x01\xac\xf9\
# ...

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt


file_data = np.frombuffer(response.content, dtype="int8")
image = cv2.imdecode(file_data, cv2.IMREAD_UNCHANGED)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.show()
